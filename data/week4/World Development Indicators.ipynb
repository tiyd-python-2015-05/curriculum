# %%
import pandas as pd

# %%
country_data = pd.read_csv("country_data/country_data.txt", sep="\t")

# %%
country_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13985 entries, 0 to 13984
# Data columns (total 8 columns):
# ﻿Country Name        13982 non-null object
# Country Code         13980 non-null object
# Series Name          13980 non-null object
# Series Code          13980 non-null object
# Scale (Precision)    13980 non-null object
# 1990 [YR1990]        9793 non-null float64
# 2000 [YR2000]        11210 non-null float64
# 2013 [YR2013]        11103 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 983.3+ KB

# %%
country_data.head()
# Out:
#   ﻿Country Name Country Code  \
# 0         World          WLD
# 1         World          WLD
# 2         World          WLD
# 3         World          WLD
# 4         World          WLD
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1                       Population growth (annual %)     SP.POP.GROW
# 2                              Surface area (sq. km)  AG.SRF.TOTL.K2
# 3  Population density (people per sq. km of land ...     EN.POP.DNST
# 4  Poverty headcount ratio at national poverty li...     SI.POV.NAHC
#
#   Scale (Precision)  1990 [YR1990]  2000 [YR2000]  2013 [YR2013]
# 0   Millions (0.00)        5278.92        6101.96         7125.1
# 1        Unit (0.0)           1.70           1.30            1.2
# 2   Thousands (0.0)      134158.10      134110.30       134324.7
# 3        Unit (0.0)          40.70          47.00           54.9
# ...

# %%
country_data.tail()
# Out:
#                                           ﻿Country Name Country Code  \
# 13980                                               NaN          NaN
# 13981                                               NaN          NaN
# 13982                                               NaN          NaN
# 13983  Data from database: World Development Indicators          NaN
# 13984                          Last Updated: 04/14/2015          NaN
#
#       Series Name Series Code Scale (Precision)  1990 [YR1990]  2000 [YR2000]  \
# 13980         NaN         NaN               NaN            NaN            NaN
# 13981         NaN         NaN               NaN            NaN            NaN
# 13982         NaN         NaN               NaN            NaN            NaN
# 13983         NaN         NaN               NaN            NaN            NaN
# 13984         NaN         NaN               NaN            NaN            NaN
#
#        2013 [YR2013]
# 13980            NaN
# 13981            NaN
# ...

# %%
country_data.dropna(thresh=2).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13980 entries, 0 to 13979
# Data columns (total 8 columns):
# ﻿Country Name        13980 non-null object
# Country Code         13980 non-null object
# Series Name          13980 non-null object
# Series Code          13980 non-null object
# Scale (Precision)    13980 non-null object
# 1990 [YR1990]        9793 non-null float64
# 2000 [YR2000]        11210 non-null float64
# 2013 [YR2013]        11103 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 983.0+ KB

# %%
cdata2 = country_data.dropna(thresh=2)

# %%
cdata2.head()
# Out:
#   ﻿Country Name Country Code  \
# 0         World          WLD
# 1         World          WLD
# 2         World          WLD
# 3         World          WLD
# 4         World          WLD
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1                       Population growth (annual %)     SP.POP.GROW
# 2                              Surface area (sq. km)  AG.SRF.TOTL.K2
# 3  Population density (people per sq. km of land ...     EN.POP.DNST
# 4  Poverty headcount ratio at national poverty li...     SI.POV.NAHC
#
#   Scale (Precision)  1990 [YR1990]  2000 [YR2000]  2013 [YR2013]
# 0   Millions (0.00)        5278.92        6101.96         7125.1
# 1        Unit (0.0)           1.70           1.30            1.2
# 2   Thousands (0.0)      134158.10      134110.30       134324.7
# 3        Unit (0.0)          40.70          47.00           54.9
# ...

# %%
cdata2.keys()[0]
# Out:
# '\ufeffCountry Name'

# %%
cdata3 = cdata2.rename(columns={'\ufeffCountry Name': "Country Name"})

# %%
cdata3.head()
# Out:
#   Country Name Country Code  \
# 0        World          WLD
# 1        World          WLD
# 2        World          WLD
# 3        World          WLD
# 4        World          WLD
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1                       Population growth (annual %)     SP.POP.GROW
# 2                              Surface area (sq. km)  AG.SRF.TOTL.K2
# 3  Population density (people per sq. km of land ...     EN.POP.DNST
# 4  Poverty headcount ratio at national poverty li...     SI.POV.NAHC
#
#   Scale (Precision)  1990 [YR1990]  2000 [YR2000]  2013 [YR2013]
# 0   Millions (0.00)        5278.92        6101.96         7125.1
# 1        Unit (0.0)           1.70           1.30            1.2
# 2   Thousands (0.0)      134158.10      134110.30       134324.7
# 3        Unit (0.0)          40.70          47.00           54.9
# ...

# %%
cdata3.pivot_table(index="Country Name", columns="Series Code", values="2013 [YR2013]").head()
# Out:
# Series Code     AG.LND.FRST.K2  AG.SRF.TOTL.K2  BX.KLT.DINV.CD.WD  \
# Country Name
# Afghanistan               13.5           652.9                 60
# Albania                    7.7            28.8               1254
# Algeria                   14.7          2381.7               1689
# American Samoa             0.2             0.2                NaN
# Andorra                    0.2             0.5                NaN
#
# Series Code     BX.TRF.PWKR.CD.DT  DT.DOD.DECT.CD  DT.ODA.ALLD.CD  \
# Country Name
# Afghanistan                   538            2577            5266
# Albania                      1094            7776             298
# Algeria                       210            5231             208
# American Samoa                NaN             NaN             NaN
# Andorra                       NaN             NaN             NaN
#
# Series Code     DT.TDS.DECT.EX.ZS  EG.USE.ELEC.KH.PC  EG.USE.PCAP.KG.OE  \
# Country Name
# ...

# %%
cdata4 = cdata3.pivot_table(index="Country Name", columns="Series Name", values="2013 [YR2013]")

# %%
cdata4.head()
# Out:
# Series Name     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Country Name
# Afghanistan                                                    83
# Albania                                                        14
# Algeria                                                        10
# American Samoa                                                NaN
# Andorra                                                       NaN
#
# Series Name     Agriculture, value added (% of GDP)  \
# Country Name
# Afghanistan                                      24
# Albania                                          22
# Algeria                                          11
# American Samoa                                  NaN
# Andorra                                         NaN
#
# Series Name     Annual freshwater withdrawals, total (% of internal resources)  \
# Country Name
# Afghanistan                                                  43.0
# ...

# %%
cdata3["Series Name"].unique()
# Out:
# array(['Population, total', 'Population growth (annual %)',
#        'Surface area (sq. km)',
#        'Population density (people per sq. km of land area)',
#        'Poverty headcount ratio at national poverty lines (% of population)',
#        'Poverty headcount ratio at $1.25 a day (PPP) (% of population)',
#        'GNI, Atlas method (current US$)',
#        'GNI per capita, Atlas method (current US$)',
#        'GNI, PPP (current international $)',
#        'GNI per capita, PPP (current international $)',
#        'Income share held by lowest 20%',
#        'Life expectancy at birth, total (years)',
#        'Fertility rate, total (births per woman)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Contraceptive prevalence (% of women ages 15-49)',
#        'Births attended by skilled health staff (% of total)',
#        'Mortality rate, under-5 (per 1,000 live births)',
# ...

# %%
cdata4['Births attended by skilled health staff (% of total)'].corr(cdata4['Mortality rate, under-5 (per 1,000 live births)'])
# Out:
# -0.77500962665200279

# %%
cdata4.corr()
# Out:
# Series Name                                         Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Series Name
# Adolescent fertility rate (births per 1,000 wom...                                           1.000000
# Agriculture, value added (% of GDP)                                                          0.587295
# Annual freshwater withdrawals, total (% of inte...                                          -0.107776
# Births attended by skilled health staff (% of t...                                          -0.577870
# CO2 emissions (metric tons per capita)                                                      -0.469305
# Cash surplus/deficit (% of GDP)                                                              0.016231
# Contraceptive prevalence (% of women ages 15-49)                                            -0.598783
# Domestic credit provided by financial sector (%...                                          -0.494006
# ...
